# %% [markdown]
# <div>
# <img src="./images/sunpy_logo.png" width="500" align="left"/>
# </div>

# %% [markdown]
# # 1. Searching and downloading data with sunpy
#
#
#
# In this notebook, an introduction to how you can search for and download data with sunpy. We will begin with an intoduction to `astropy.units` (which are used throughout the sunpy ecosystem), and then look about how to use `Fido` and build queries for data. In particular, this notebook will look at the following:
#
# 1. Introduction to `astropy.units`
# 2. Overview of `Fido`
# 3. Constructing a data search query and inspecting it
# 4. More complex queries and the HEK
# 5. Extending Fido - the SOAR archive

# %%
import astropy.units as u

from sunpy.net import Fido, attrs as a
from sunpy.time import parse_time

# sunpy_soar is an affiliated package of SunPy 
# and registers the SOAR to be searched by Fido
import sunpy_soar

import numpy as np

# %% [markdown]
# ## 1.1 Astropy Units - a quick overview
# [`astropy.units`](https://docs.astropy.org/en/stable/units/) provides a means to deal with and handle numbers/arrays etc that have an associated physical quantity (e.g. km, seconds, Kelvin). Throughout SunPy, any physical input or outputs is an [`astropy.Quantity`](https://docs.astropy.org/en/stable/units/quantity.html#quantity). Lets look at how we can create and convert between astropy units. Above we have imported `astropy.units` as `u`

# %%
distance_in_km = 10*u.km

# %%
distance_in_km
# Out:
# <Quantity 10. km>

# %%
distance_in_km.unit
# Out:
# Unit("km")

# %%
distance_in_km.value
# Out:
# np.float64(10.0)

# %% [markdown]
# We can convert between equivalent units

# %%
distance_in_km.cgs
# Out:
# <Quantity 1000000. cm>

# %%
distance_in_km.to(u.parsec)
# Out:
# <Quantity 3.24077929e-13 pc>

# %%
distance_in_km.to(u.Mm)
# Out:
# <Quantity 0.01 Mm>

# %% [markdown]
# However you can only convert between physical units that make sense for example:

# %%
#distance_in_km.to(u.second)

# %%
time_in_sec = 60*u.s

# %%
(distance_in_km/time_in_sec).unit
# Out:
# Unit("km / s")

# %%
(10*u.Angstrom).to(u.nm)
# Out:
# <Quantity 1. nm>

# %% [markdown]
# # 1.2 Overview of sunpy's Fido Unified Downloader
# Fido is sunpy's interface for searching and downloading solar physics data.
# It offers a unified interface for searching and fetching data irrespective of the underlying client or webservice from where the data is obtained.
# You can also search and accesses multiple instruments and all available data providers in a single query.
# It supplies a single, easy, consistent and extendable way to get most forms of solar physics data the community need.
#
# For more information about Fido and how to use it check out the documentation on our website: https://docs.sunpy.org/en/stable/tutorial/acquiring_data/index.html
#
# Fido offers access to data available through:
#
# * VSO (Virtual Solar Observatory)
# * JSOC (through drms)
# * Individual data providers from web accessible sources (http, ftp, etc)
# * CDAWeb
# * HEK
# * HELIO
#
# As described here Fido provides access to many sources of data through different clients, these clients can be defined inside sunpy or in other packages (e.g. DKIST data can be accessed using Fido through [DKIST User Tools](https://docs.dkist.nso.edu/projects/python-tools/en/latest/tutorial/2_search_and_asdf_download.html)).

# %% [markdown]
# #### Importantly, Solar Orbiter data can be accessed through the client defined in the `sunpy_soar` affiliated package.
# The SOAR client is registered once we install `sunpy_soar` above. Without installing it, it wont be registered within Fido.
#
# Lets first inspect the clients that are available through Fido:

# %%
Fido
# Out:
# <sunpy.net.fido_factory.UnifiedDownloaderFactory object at 0x1482bd160>
# sunpy.net.Fido
#
# Fido is a unified data search and retrieval tool.
#
# It provides simultaneous access to a variety of online data sources, some
# cover multiple instruments and data products like the Virtual Solar
# Observatory and some are specific to a single source.
#
# For details of using `~sunpy.net.Fido` see :ref:`sunpy-tutorial-acquiring-data-index`.
#
#
#       Client      ...
# ----------------- ...
# CDAWEBClient      ...
# ADAPTClient       ...
# AIASynopsisClient ...
# EVEClient         ...
# GBMClient         ...
# XRSClient         ...
# SUVIClient        ...
# GONGClient        ...
# LYRAClient        ...
# NOAAIndicesClient ...
# NOAAPredictClient ...
# SRSClient         ...
# NoRHClient        ...
# RHESSIClient      ...
# HEKClient         ...
# HECClient         ...
# JSOCClient        ...
# SOLARNETClient    ...
# VSOClient         ...
# SOARClient        ...

# %% [markdown]
# ### Using attributes to search for data with Fido
#
# Sunpy uses specified **attributes** to search for data using Fido. The range of these attributes is located in the `attrs` submodule. These `attr` parameters can be combined together to construct data search queries, such as searching over a certain time period, for data from a certain instrument with a certain wavelength etc.
#
# Different clients and provides will have client-specific attributes, but the core attributes are:
#
# * `a.Time`
# * `a.Instrument`
# * `a.Wavelength`
#
#
# Lets look at how these attributes work in more detail.
#
# First we can look at `a.Time`, which is used to specify the timerange of a query.

# %%
a.Time("2022-04-02 12:00", "2022-04-02 15:00")
# Out:
# <sunpy.net.attrs.Time(2022-04-02 12:00:00.000, 2022-04-02 15:00:00.000)>

# %% [markdown]
# We can inspect the instrument attribute to see what instrument `attrs` are currently supported through sunpy. Here we can see the instrument name (i.e. the name to be passed to the `a.Instrument` attribute, the client from which the data is available to access, and the full name of the instrument.)

# %%
a.Instrument
# Out:
# <class 'sunpy.net.attrs.Instrument'>
# sunpy.net.attrs.Instrument
#
# Specifies the Instrument name for the search.
#
#        Attribute Name       ...
# --------------------------- ...
# adapt                       ...
# aia                         ...
# aia                         ...
# bcs                         ...
# be_continuum                ...
# be_halpha                   ...
# bigbear                     ...
# c1                          ...
# c2                          ...
# caii                        ...
# cds                         ...
# celias                      ...
# cerrotololo                 ...
# chp                         ...
# cook                        ...
# costep                      ...
# cp                          ...
# dpm                         ...
# eis                         ...
# eit                         ...
# elteide                     ...
# epd                         ...
# erne                        ...
# eui                         ...
# eui                         ...
# eve                         ...
# eve                         ...
# film                        ...
# five_12_channelmagnetograph ...
# foxsi                       ...
# gbm                         ...
# goes                        ...
# golf                        ...
# gong                        ...
# ha2                         ...
# hi_c                        ...
# hi_c21                      ...
# hmi                         ...
# hxeclipse                   ...
# hxt                         ...
# imax                        ...
# impact                      ...
# iris                        ...
# isoon                       ...
# iss                         ...
# ivm                         ...
# k_cor                       ...
# kpdc                        ...
# l1                          ...
# l2                          ...
# lasco                       ...
# learmonth                   ...
# longwave_lobe_06            ...
# longwave_lobe_07            ...
# longwave_slit_06            ...
# longwave_slit_07            ...
# lyra                        ...
# lyra                        ...
# mag                         ...
# maunaloa                    ...
# mdi                         ...
# mees                        ...
# mergedgong                  ...
# metis                       ...
# metis                       ...
# meudonspectroheliograph     ...
# mk4                         ...
# nfi_0                       ...
# noaa_indices                ...
# noaa_predict                ...
# norh                        ...
# phi                         ...
# phi                         ...
# phoenix                     ...
# phoka                       ...
# plastic                     ...
# polar                       ...
# ptmc                        ...
# rhessi                      ...
# rhessi                      ...
# rpw                         ...
# secchi                      ...
# shortwave_lobe_06           ...
# shortwave_lobe_07           ...
# shortwave_slit_06           ...
# shortwave_slit_07           ...
# six_0_ftshg                 ...
# sj                          ...
# solarftsspectrometer        ...
# solohi                      ...
# solohi                      ...
# soon                        ...
# sot                         ...
# sp1                         ...
# sp2                         ...
# spectroheliograph           ...
# spectromagnetograph         ...
# spice                       ...
# spice                       ...
# srs_table                   ...
# stix                        ...
# stix                        ...
# sufi                        ...
# sumer                       ...
# sutri                       ...
# suvi                        ...
# suvi                        ...
# swa                         ...
# swan                        ...
# swap                        ...
# swaves                      ...
# sxt                         ...
# t1_halpha                   ...
# t4_cak                      ...
# t4_continuum                ...
# t4_gband                    ...
# tm_1001                     ...
# tm_1010                     ...
# trace                       ...
# udaipur                     ...
# unpolarized                 ...
# uvcs                        ...
# vault_1999                  ...
# vault_2002                  ...
# vault_2014                  ...
# virgo                       ...
# vsm                         ...
# wbs                         ...
# wfi_1                       ...
# wfi_2                       ...
# wfi_3                       ...
# wispr                       ...
# x123                        ...
# xrs                         ...
# xrt                         ...

# %% [markdown]
# sunpy also now provides tab completion to auto-fill the attribute name

# %%
a.Instrument.eit
# Out:
# <sunpy.net.attrs.Instrument(EIT: Extreme ultraviolet Imaging Telescope) object at 0x1482f3ef0>

# %% [markdown]
# To search for certain wavelengths, we need to specify the input as an `astropy.Quantity` which is a the combination of a value and an associated unit. This is something is universal in the sunpy stack - that every physical input/output is a `Quantity`.

# %%
a.Wavelength(17.1*u.angstrom)
# Out:
# <sunpy.net.attrs.Wavelength(17.1, 17.1, 'Angstrom')>

# %%
import sunpy

# %% [markdown]
# ## 3. Constructing a search query
#  ### A simple query
#
# Lets create a simple query to search for data from AIA over a particular time period

# %%
result = Fido.search(a.Time("2022-04-02 12:00", "2022-04-02 15:00"), 
                     a.Instrument("AIA"))

# %%
result
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object at 0x13ffdf380>
# Results from 1 Provider:
#
# 174 Results from the VSOClient:
# Source: https://sdac.virtualsolar.org/cgi/search
# Data retrieval status: http://docs.virtualsolar.org/wiki/VSOHealthReport
# Total estimated size: 488.147 Gbyte
#
#        Start Time               End Time        Source Instrument    Wavelength    Provider  Physobs  Wavetype Extent Width Extent Length Extent Type    Size    Extra Flags
#                                                                       Angstrom                                                                          Mibyte
# ----------------------- ----------------------- ------ ---------- ---------------- -------- --------- -------- ------------ ------------- ----------- ---------- -----------
# 2022-04-02 12:00:00.000 2022-04-02 12:09:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3038.47656           S
# 2022-04-02 12:00:04.000 2022-04-02 12:09:17.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3038.47656           S
# 2022-04-02 12:00:05.000 2022-04-02 12:00:06.000    SDO        AIA 4500.0 .. 4500.0     JSOC intensity   NARROW         4096          4096    FULLDISK   64.64844           S
# 2022-04-02 12:00:05.000 2022-04-02 12:09:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3038.47656           S
# 2022-04-02 12:00:06.000 2022-04-02 12:09:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3038.47656           S
# 2022-04-02 12:00:09.000 2022-04-02 12:09:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 2973.82812           S
# 2022-04-02 12:00:09.000 2022-04-02 12:09:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3038.47656           S
# 2022-04-02 12:00:11.000 2022-04-02 12:09:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 2973.82812           S
# 2022-04-02 12:00:14.000 2022-04-02 12:09:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1486.91406           S
# 2022-04-02 12:00:28.000 2022-04-02 12:09:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1486.91406           S
# 2022-04-02 12:09:21.000 2022-04-02 12:19:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:09:23.000 2022-04-02 12:19:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:09:24.000 2022-04-02 12:19:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:09:26.000 2022-04-02 12:19:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 12:09:28.000 2022-04-02 12:19:17.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:09:29.000 2022-04-02 12:19:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:09:30.000 2022-04-02 12:19:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:09:33.000 2022-04-02 12:19:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:09:40.000 2022-04-02 12:19:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 12:19:21.000 2022-04-02 12:29:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:19:23.000 2022-04-02 12:29:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:19:24.000 2022-04-02 12:29:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:19:26.000 2022-04-02 12:29:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 12:19:28.000 2022-04-02 12:29:17.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:19:29.000 2022-04-02 12:29:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:19:30.000 2022-04-02 12:29:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:19:33.000 2022-04-02 12:29:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:19:40.000 2022-04-02 12:29:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 12:29:21.000 2022-04-02 12:39:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:29:23.000 2022-04-02 12:39:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:29:24.000 2022-04-02 12:39:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:29:26.000 2022-04-02 12:39:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 12:29:28.000 2022-04-02 12:39:17.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:29:29.000 2022-04-02 12:39:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:29:30.000 2022-04-02 12:39:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:29:33.000 2022-04-02 12:39:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:29:40.000 2022-04-02 12:39:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 12:39:21.000 2022-04-02 12:49:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:39:23.000 2022-04-02 12:49:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:39:24.000 2022-04-02 12:49:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:39:26.000 2022-04-02 12:49:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 12:39:28.000 2022-04-02 12:49:17.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:39:29.000 2022-04-02 12:49:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:39:30.000 2022-04-02 12:49:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:39:33.000 2022-04-02 12:49:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:39:40.000 2022-04-02 12:49:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 12:49:21.000 2022-04-02 12:59:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:49:23.000 2022-04-02 12:59:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:49:24.000 2022-04-02 12:59:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:49:26.000 2022-04-02 12:59:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 12:49:28.000 2022-04-02 12:59:17.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:49:29.000 2022-04-02 12:59:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:49:30.000 2022-04-02 12:59:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:49:33.000 2022-04-02 12:59:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:49:40.000 2022-04-02 12:59:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 12:59:21.000 2022-04-02 13:09:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:59:23.000 2022-04-02 13:09:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:59:24.000 2022-04-02 13:09:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:59:26.000 2022-04-02 13:09:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 12:59:28.000 2022-04-02 13:09:17.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:59:29.000 2022-04-02 13:09:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:59:30.000 2022-04-02 13:09:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:59:33.000 2022-04-02 13:09:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 12:59:40.000 2022-04-02 13:09:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK  1551.5625           S
# 2022-04-02 13:00:05.000 2022-04-02 13:00:06.000    SDO        AIA 4500.0 .. 4500.0     JSOC intensity   NARROW         4096          4096    FULLDISK   64.64844           S
# 2022-04-02 13:09:21.000 2022-04-02 13:19:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:09:23.000 2022-04-02 13:19:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:09:24.000 2022-04-02 13:19:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:09:26.000 2022-04-02 13:19:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 13:09:28.000 2022-04-02 13:19:17.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:09:29.000 2022-04-02 13:19:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:09:30.000 2022-04-02 13:19:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:09:33.000 2022-04-02 13:19:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:09:40.000 2022-04-02 13:19:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 13:19:21.000 2022-04-02 13:29:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:19:23.000 2022-04-02 13:29:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:19:24.000 2022-04-02 13:29:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:19:26.000 2022-04-02 13:29:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 13:19:28.000 2022-04-02 13:29:19.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:19:29.000 2022-04-02 13:29:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:19:30.000 2022-04-02 13:29:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:19:33.000 2022-04-02 13:29:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:19:40.000 2022-04-02 13:29:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 13:29:21.000 2022-04-02 13:39:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:29:23.000 2022-04-02 13:39:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:29:24.000 2022-04-02 13:39:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:29:26.000 2022-04-02 13:39:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 13:29:28.000 2022-04-02 13:39:17.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:29:29.000 2022-04-02 13:39:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:29:30.000 2022-04-02 13:39:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:29:33.000 2022-04-02 13:39:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:29:40.000 2022-04-02 13:39:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 13:39:21.000 2022-04-02 13:49:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:39:23.000 2022-04-02 13:49:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:39:24.000 2022-04-02 13:49:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:39:26.000 2022-04-02 13:49:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 13:39:28.000 2022-04-02 13:49:18.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:39:29.000 2022-04-02 13:49:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:39:30.000 2022-04-02 13:49:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:39:33.000 2022-04-02 13:49:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:39:40.000 2022-04-02 13:49:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 13:49:21.000 2022-04-02 13:59:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:49:23.000 2022-04-02 13:59:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:49:24.000 2022-04-02 13:59:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:49:26.000 2022-04-02 13:59:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 13:49:28.000 2022-04-02 13:59:19.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:49:29.000 2022-04-02 13:59:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:49:30.000 2022-04-02 13:59:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:49:33.000 2022-04-02 13:59:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:49:40.000 2022-04-02 13:59:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 13:59:21.000 2022-04-02 14:09:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:59:23.000 2022-04-02 14:09:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:59:24.000 2022-04-02 14:09:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:59:26.000 2022-04-02 14:09:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 13:59:28.000 2022-04-02 14:09:17.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:59:29.000 2022-04-02 14:09:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:59:30.000 2022-04-02 14:09:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:59:33.000 2022-04-02 14:09:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 13:59:40.000 2022-04-02 14:09:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK  1551.5625           S
# 2022-04-02 14:00:05.000 2022-04-02 14:00:06.000    SDO        AIA 4500.0 .. 4500.0     JSOC intensity   NARROW         4096          4096    FULLDISK   64.64844           S
# 2022-04-02 14:09:21.000 2022-04-02 14:19:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:09:23.000 2022-04-02 14:19:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:09:24.000 2022-04-02 14:19:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:09:26.000 2022-04-02 14:19:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 14:09:28.000 2022-04-02 14:19:19.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:09:29.000 2022-04-02 14:19:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:09:30.000 2022-04-02 14:19:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:09:33.000 2022-04-02 14:19:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:09:40.000 2022-04-02 14:19:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 14:19:23.000 2022-04-02 14:29:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:19:23.000 2022-04-02 14:29:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:19:24.000 2022-04-02 14:29:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:19:26.000 2022-04-02 14:29:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 14:19:28.000 2022-04-02 14:29:20.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:19:29.000 2022-04-02 14:29:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:19:30.000 2022-04-02 14:29:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:19:33.000 2022-04-02 14:29:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:19:40.000 2022-04-02 14:29:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 14:29:21.000 2022-04-02 14:39:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:29:23.000 2022-04-02 14:39:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:29:24.000 2022-04-02 14:39:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:29:26.000 2022-04-02 14:39:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 14:29:28.000 2022-04-02 14:39:18.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:29:29.000 2022-04-02 14:39:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:29:30.000 2022-04-02 14:39:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:29:33.000 2022-04-02 14:39:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:29:40.000 2022-04-02 14:39:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 14:39:21.000 2022-04-02 14:49:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:39:23.000 2022-04-02 14:49:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:39:24.000 2022-04-02 14:49:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:39:26.000 2022-04-02 14:49:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 14:39:28.000 2022-04-02 14:49:17.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:39:29.000 2022-04-02 14:49:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:39:30.000 2022-04-02 14:49:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:39:33.000 2022-04-02 14:49:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:39:40.000 2022-04-02 14:49:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 14:49:21.000 2022-04-02 14:59:10.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:49:23.000 2022-04-02 14:59:12.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:49:24.000 2022-04-02 14:59:13.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:49:26.000 2022-04-02 14:59:03.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 14:49:28.000 2022-04-02 14:59:19.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:49:29.000 2022-04-02 14:59:18.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:49:30.000 2022-04-02 14:59:19.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:49:33.000 2022-04-02 14:59:22.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK 3232.42188           S
# 2022-04-02 14:49:40.000 2022-04-02 14:59:17.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK 1616.21094           S
# 2022-04-02 14:59:21.000 2022-04-02 14:59:58.000    SDO        AIA   211.0 .. 211.0     JSOC intensity   NARROW         4096          4096    FULLDISK  258.59375           S
# 2022-04-02 14:59:23.000 2022-04-02 15:00:00.000    SDO        AIA     94.0 .. 94.0     JSOC intensity   NARROW         4096          4096    FULLDISK  258.59375           S
# 2022-04-02 14:59:24.000 2022-04-02 15:00:01.000    SDO        AIA   335.0 .. 335.0     JSOC intensity   NARROW         4096          4096    FULLDISK  258.59375           S
# 2022-04-02 14:59:26.000 2022-04-02 14:59:51.000    SDO        AIA 1600.0 .. 1600.0     JSOC intensity   NARROW         4096          4096    FULLDISK  129.29688           S
# 2022-04-02 14:59:28.000 2022-04-02 14:59:53.000    SDO        AIA   193.0 .. 193.0     JSOC intensity   NARROW         4096          4096    FULLDISK  193.94531           S
# 2022-04-02 14:59:29.000 2022-04-02 14:59:54.000    SDO        AIA   304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK  193.94531           S
# 2022-04-02 14:59:30.000 2022-04-02 14:59:55.000    SDO        AIA   131.0 .. 131.0     JSOC intensity   NARROW         4096          4096    FULLDISK  193.94531           S
# 2022-04-02 14:59:33.000 2022-04-02 14:59:58.000    SDO        AIA   171.0 .. 171.0     JSOC intensity   NARROW         4096          4096    FULLDISK  193.94531           S
# 2022-04-02 14:59:40.000 2022-04-02 14:59:41.000    SDO        AIA 1700.0 .. 1700.0     JSOC intensity   NARROW         4096          4096    FULLDISK   64.64844           S

# %% [markdown]
# Now lets make our query a bit more specific, say, say we only want one wavelength band from AIA. This can be achieved by specifying the `Wavelength` attribute within the search. The `a.Wavelength` attribute is passed as an `astropy.Quantity`:

# %%
result = Fido.search(a.Time("2022-04-02 12:00", "2022-04-02 15:00"), 
                     a.Instrument("AIA"), 
                     a.Wavelength(304*u.angstrom))

# %%
result
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object at 0x13feff860>
# Results from 1 Provider:
#
# 900 Results from the VSOClient:
# Source: https://sdac.virtualsolar.org/cgi/search
# Data retrieval status: http://docs.virtualsolar.org/wiki/VSOHealthReport
# Total estimated size: 61.01 Gbyte
#
#        Start Time               End Time        Source Instrument   Wavelength   Provider  Physobs  Wavetype Extent Width Extent Length Extent Type   Size
#                                                                      Angstrom                                                                        Mibyte
# ----------------------- ----------------------- ------ ---------- -------------- -------- --------- -------- ------------ ------------- ----------- --------
# 2022-04-02 12:00:05.000 2022-04-02 12:00:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:00:17.000 2022-04-02 12:00:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:00:29.000 2022-04-02 12:00:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:00:41.000 2022-04-02 12:00:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:00:53.000 2022-04-02 12:00:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:01:05.000 2022-04-02 12:01:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:01:17.000 2022-04-02 12:01:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:01:29.000 2022-04-02 12:01:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:01:41.000 2022-04-02 12:01:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:01:53.000 2022-04-02 12:01:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:02:05.000 2022-04-02 12:02:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:02:17.000 2022-04-02 12:02:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:02:29.000 2022-04-02 12:02:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:02:41.000 2022-04-02 12:02:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:02:53.000 2022-04-02 12:02:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:03:05.000 2022-04-02 12:03:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:03:17.000 2022-04-02 12:03:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:03:29.000 2022-04-02 12:03:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:03:41.000 2022-04-02 12:03:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:03:53.000 2022-04-02 12:03:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:04:05.000 2022-04-02 12:04:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:04:17.000 2022-04-02 12:04:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:04:29.000 2022-04-02 12:04:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:04:41.000 2022-04-02 12:04:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:04:53.000 2022-04-02 12:04:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:05:05.000 2022-04-02 12:05:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:05:17.000 2022-04-02 12:05:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:05:29.000 2022-04-02 12:05:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:05:41.000 2022-04-02 12:05:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:05:53.000 2022-04-02 12:05:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:06:05.000 2022-04-02 12:06:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:06:17.000 2022-04-02 12:06:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:06:29.000 2022-04-02 12:06:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:06:41.000 2022-04-02 12:06:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:06:53.000 2022-04-02 12:06:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:07:05.000 2022-04-02 12:07:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:07:17.000 2022-04-02 12:07:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:07:29.000 2022-04-02 12:07:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:07:41.000 2022-04-02 12:07:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:07:53.000 2022-04-02 12:07:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:08:05.000 2022-04-02 12:08:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:08:17.000 2022-04-02 12:08:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:08:29.000 2022-04-02 12:08:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:08:41.000 2022-04-02 12:08:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:08:53.000 2022-04-02 12:08:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:09:05.000 2022-04-02 12:09:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:09:17.000 2022-04-02 12:09:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:09:29.000 2022-04-02 12:09:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:09:41.000 2022-04-02 12:09:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:09:53.000 2022-04-02 12:09:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:10:05.000 2022-04-02 12:10:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:10:17.000 2022-04-02 12:10:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:10:29.000 2022-04-02 12:10:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:10:41.000 2022-04-02 12:10:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:10:53.000 2022-04-02 12:10:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:11:05.000 2022-04-02 12:11:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:11:17.000 2022-04-02 12:11:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:11:29.000 2022-04-02 12:11:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:11:41.000 2022-04-02 12:11:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:11:53.000 2022-04-02 12:11:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:12:05.000 2022-04-02 12:12:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:12:17.000 2022-04-02 12:12:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:12:29.000 2022-04-02 12:12:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:12:41.000 2022-04-02 12:12:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:12:53.000 2022-04-02 12:12:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:13:05.000 2022-04-02 12:13:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:13:17.000 2022-04-02 12:13:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:13:29.000 2022-04-02 12:13:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:13:41.000 2022-04-02 12:13:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:13:53.000 2022-04-02 12:13:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:14:05.000 2022-04-02 12:14:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:14:17.000 2022-04-02 12:14:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:14:29.000 2022-04-02 12:14:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:14:41.000 2022-04-02 12:14:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:14:53.000 2022-04-02 12:14:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:15:05.000 2022-04-02 12:15:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:15:17.000 2022-04-02 12:15:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:15:29.000 2022-04-02 12:15:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:15:41.000 2022-04-02 12:15:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:15:53.000 2022-04-02 12:15:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:16:05.000 2022-04-02 12:16:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:16:17.000 2022-04-02 12:16:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:16:29.000 2022-04-02 12:16:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:16:41.000 2022-04-02 12:16:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:16:53.000 2022-04-02 12:16:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:17:05.000 2022-04-02 12:17:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:17:17.000 2022-04-02 12:17:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:17:29.000 2022-04-02 12:17:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:17:41.000 2022-04-02 12:17:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:17:53.000 2022-04-02 12:17:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:18:05.000 2022-04-02 12:18:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:18:17.000 2022-04-02 12:18:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:18:29.000 2022-04-02 12:18:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:18:41.000 2022-04-02 12:18:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:18:53.000 2022-04-02 12:18:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:19:05.000 2022-04-02 12:19:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:19:17.000 2022-04-02 12:19:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:19:29.000 2022-04-02 12:19:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:19:41.000 2022-04-02 12:19:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:19:53.000 2022-04-02 12:19:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:20:05.000 2022-04-02 12:20:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:20:17.000 2022-04-02 12:20:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:20:29.000 2022-04-02 12:20:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:20:41.000 2022-04-02 12:20:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:20:53.000 2022-04-02 12:20:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:21:05.000 2022-04-02 12:21:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:21:17.000 2022-04-02 12:21:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:21:29.000 2022-04-02 12:21:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:21:41.000 2022-04-02 12:21:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:21:53.000 2022-04-02 12:21:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:22:05.000 2022-04-02 12:22:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:22:17.000 2022-04-02 12:22:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:22:29.000 2022-04-02 12:22:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:22:41.000 2022-04-02 12:22:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:22:53.000 2022-04-02 12:22:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:23:05.000 2022-04-02 12:23:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:23:17.000 2022-04-02 12:23:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:23:29.000 2022-04-02 12:23:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:23:41.000 2022-04-02 12:23:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:23:53.000 2022-04-02 12:23:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:24:05.000 2022-04-02 12:24:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:24:17.000 2022-04-02 12:24:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:24:29.000 2022-04-02 12:24:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:24:41.000 2022-04-02 12:24:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:24:53.000 2022-04-02 12:24:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:25:05.000 2022-04-02 12:25:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:25:17.000 2022-04-02 12:25:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:25:29.000 2022-04-02 12:25:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:25:41.000 2022-04-02 12:25:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:25:53.000 2022-04-02 12:25:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:26:05.000 2022-04-02 12:26:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:26:17.000 2022-04-02 12:26:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:26:29.000 2022-04-02 12:26:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:26:41.000 2022-04-02 12:26:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:26:53.000 2022-04-02 12:26:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:27:05.000 2022-04-02 12:27:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:27:17.000 2022-04-02 12:27:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:27:29.000 2022-04-02 12:27:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:27:41.000 2022-04-02 12:27:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:27:53.000 2022-04-02 12:27:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:28:05.000 2022-04-02 12:28:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:28:17.000 2022-04-02 12:28:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:28:29.000 2022-04-02 12:28:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:28:41.000 2022-04-02 12:28:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:28:53.000 2022-04-02 12:28:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:29:05.000 2022-04-02 12:29:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:29:17.000 2022-04-02 12:29:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:29:29.000 2022-04-02 12:29:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:29:41.000 2022-04-02 12:29:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:29:53.000 2022-04-02 12:29:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:30:05.000 2022-04-02 12:30:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:30:17.000 2022-04-02 12:30:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:30:29.000 2022-04-02 12:30:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:30:41.000 2022-04-02 12:30:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:30:53.000 2022-04-02 12:30:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:31:05.000 2022-04-02 12:31:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:31:17.000 2022-04-02 12:31:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:31:29.000 2022-04-02 12:31:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:31:41.000 2022-04-02 12:31:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:31:53.000 2022-04-02 12:31:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:32:05.000 2022-04-02 12:32:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:32:17.000 2022-04-02 12:32:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:32:29.000 2022-04-02 12:32:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:32:41.000 2022-04-02 12:32:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:32:53.000 2022-04-02 12:32:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:33:05.000 2022-04-02 12:33:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:33:17.000 2022-04-02 12:33:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:33:29.000 2022-04-02 12:33:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:33:41.000 2022-04-02 12:33:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:33:53.000 2022-04-02 12:33:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:34:05.000 2022-04-02 12:34:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:34:17.000 2022-04-02 12:34:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:34:29.000 2022-04-02 12:34:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:34:41.000 2022-04-02 12:34:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:34:53.000 2022-04-02 12:34:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:35:05.000 2022-04-02 12:35:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:35:17.000 2022-04-02 12:35:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:35:29.000 2022-04-02 12:35:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:35:41.000 2022-04-02 12:35:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:35:53.000 2022-04-02 12:35:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:36:05.000 2022-04-02 12:36:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:36:17.000 2022-04-02 12:36:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:36:29.000 2022-04-02 12:36:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:36:41.000 2022-04-02 12:36:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:36:53.000 2022-04-02 12:36:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:37:05.000 2022-04-02 12:37:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:37:17.000 2022-04-02 12:37:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:37:29.000 2022-04-02 12:37:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:37:41.000 2022-04-02 12:37:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:37:53.000 2022-04-02 12:37:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:38:05.000 2022-04-02 12:38:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:38:17.000 2022-04-02 12:38:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:38:29.000 2022-04-02 12:38:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:38:41.000 2022-04-02 12:38:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:38:53.000 2022-04-02 12:38:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:39:05.000 2022-04-02 12:39:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:39:17.000 2022-04-02 12:39:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:39:29.000 2022-04-02 12:39:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:39:41.000 2022-04-02 12:39:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:39:53.000 2022-04-02 12:39:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:40:05.000 2022-04-02 12:40:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:40:17.000 2022-04-02 12:40:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:40:29.000 2022-04-02 12:40:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:40:41.000 2022-04-02 12:40:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:40:53.000 2022-04-02 12:40:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:41:05.000 2022-04-02 12:41:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:41:17.000 2022-04-02 12:41:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:41:29.000 2022-04-02 12:41:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:41:41.000 2022-04-02 12:41:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:41:53.000 2022-04-02 12:41:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:42:05.000 2022-04-02 12:42:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:42:17.000 2022-04-02 12:42:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:42:29.000 2022-04-02 12:42:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:42:41.000 2022-04-02 12:42:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:42:53.000 2022-04-02 12:42:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:43:05.000 2022-04-02 12:43:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:43:17.000 2022-04-02 12:43:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:43:29.000 2022-04-02 12:43:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:43:41.000 2022-04-02 12:43:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:43:53.000 2022-04-02 12:43:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:44:05.000 2022-04-02 12:44:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:44:17.000 2022-04-02 12:44:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:44:29.000 2022-04-02 12:44:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:44:41.000 2022-04-02 12:44:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:44:53.000 2022-04-02 12:44:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:45:05.000 2022-04-02 12:45:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:45:17.000 2022-04-02 12:45:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:45:29.000 2022-04-02 12:45:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:45:41.000 2022-04-02 12:45:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:45:53.000 2022-04-02 12:45:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:46:05.000 2022-04-02 12:46:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:46:17.000 2022-04-02 12:46:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:46:29.000 2022-04-02 12:46:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:46:41.000 2022-04-02 12:46:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:46:53.000 2022-04-02 12:46:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:47:05.000 2022-04-02 12:47:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:47:17.000 2022-04-02 12:47:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:47:29.000 2022-04-02 12:47:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:47:41.000 2022-04-02 12:47:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:47:53.000 2022-04-02 12:47:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:48:05.000 2022-04-02 12:48:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:48:17.000 2022-04-02 12:48:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:48:29.000 2022-04-02 12:48:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:48:41.000 2022-04-02 12:48:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:48:53.000 2022-04-02 12:48:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:49:05.000 2022-04-02 12:49:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:49:17.000 2022-04-02 12:49:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:49:29.000 2022-04-02 12:49:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:49:41.000 2022-04-02 12:49:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:49:53.000 2022-04-02 12:49:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:50:05.000 2022-04-02 12:50:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:50:17.000 2022-04-02 12:50:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:50:29.000 2022-04-02 12:50:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:50:41.000 2022-04-02 12:50:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:50:53.000 2022-04-02 12:50:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:51:05.000 2022-04-02 12:51:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:51:17.000 2022-04-02 12:51:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:51:29.000 2022-04-02 12:51:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:51:41.000 2022-04-02 12:51:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:51:53.000 2022-04-02 12:51:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:52:05.000 2022-04-02 12:52:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:52:17.000 2022-04-02 12:52:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:52:29.000 2022-04-02 12:52:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:52:41.000 2022-04-02 12:52:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:52:53.000 2022-04-02 12:52:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:53:05.000 2022-04-02 12:53:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:53:17.000 2022-04-02 12:53:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:53:29.000 2022-04-02 12:53:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:53:41.000 2022-04-02 12:53:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:53:53.000 2022-04-02 12:53:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:54:05.000 2022-04-02 12:54:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:54:17.000 2022-04-02 12:54:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:54:29.000 2022-04-02 12:54:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:54:41.000 2022-04-02 12:54:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:54:53.000 2022-04-02 12:54:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:55:05.000 2022-04-02 12:55:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:55:17.000 2022-04-02 12:55:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:55:29.000 2022-04-02 12:55:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:55:41.000 2022-04-02 12:55:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:55:53.000 2022-04-02 12:55:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:56:05.000 2022-04-02 12:56:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:56:17.000 2022-04-02 12:56:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:56:29.000 2022-04-02 12:56:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:56:41.000 2022-04-02 12:56:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:56:53.000 2022-04-02 12:56:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:57:05.000 2022-04-02 12:57:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:57:17.000 2022-04-02 12:57:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:57:29.000 2022-04-02 12:57:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:57:41.000 2022-04-02 12:57:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:57:53.000 2022-04-02 12:57:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:58:05.000 2022-04-02 12:58:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:58:17.000 2022-04-02 12:58:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:58:29.000 2022-04-02 12:58:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:58:41.000 2022-04-02 12:58:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:58:53.000 2022-04-02 12:58:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:59:05.000 2022-04-02 12:59:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:59:17.000 2022-04-02 12:59:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:59:29.000 2022-04-02 12:59:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:59:41.000 2022-04-02 12:59:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 12:59:53.000 2022-04-02 12:59:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# ...
# 2022-04-02 14:39:53.000 2022-04-02 14:39:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:40:05.000 2022-04-02 14:40:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:40:17.000 2022-04-02 14:40:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:40:29.000 2022-04-02 14:40:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:40:41.000 2022-04-02 14:40:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:40:53.000 2022-04-02 14:40:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:41:05.000 2022-04-02 14:41:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:41:17.000 2022-04-02 14:41:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:41:29.000 2022-04-02 14:41:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:41:41.000 2022-04-02 14:41:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:41:53.000 2022-04-02 14:41:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:42:05.000 2022-04-02 14:42:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:42:17.000 2022-04-02 14:42:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:42:29.000 2022-04-02 14:42:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:42:41.000 2022-04-02 14:42:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:42:53.000 2022-04-02 14:42:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:43:05.000 2022-04-02 14:43:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:43:17.000 2022-04-02 14:43:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:43:29.000 2022-04-02 14:43:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:43:41.000 2022-04-02 14:43:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:43:53.000 2022-04-02 14:43:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:44:05.000 2022-04-02 14:44:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:44:17.000 2022-04-02 14:44:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:44:29.000 2022-04-02 14:44:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:44:41.000 2022-04-02 14:44:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:44:53.000 2022-04-02 14:44:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:45:05.000 2022-04-02 14:45:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:45:17.000 2022-04-02 14:45:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:45:29.000 2022-04-02 14:45:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:45:41.000 2022-04-02 14:45:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:45:53.000 2022-04-02 14:45:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:46:05.000 2022-04-02 14:46:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:46:17.000 2022-04-02 14:46:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:46:29.000 2022-04-02 14:46:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:46:41.000 2022-04-02 14:46:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:46:53.000 2022-04-02 14:46:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:47:05.000 2022-04-02 14:47:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:47:17.000 2022-04-02 14:47:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:47:29.000 2022-04-02 14:47:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:47:41.000 2022-04-02 14:47:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:47:53.000 2022-04-02 14:47:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:48:05.000 2022-04-02 14:48:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:48:17.000 2022-04-02 14:48:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:48:29.000 2022-04-02 14:48:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:48:41.000 2022-04-02 14:48:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:48:53.000 2022-04-02 14:48:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:49:05.000 2022-04-02 14:49:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:49:17.000 2022-04-02 14:49:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:49:29.000 2022-04-02 14:49:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:49:41.000 2022-04-02 14:49:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:49:53.000 2022-04-02 14:49:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:50:05.000 2022-04-02 14:50:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:50:17.000 2022-04-02 14:50:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:50:29.000 2022-04-02 14:50:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:50:41.000 2022-04-02 14:50:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:50:53.000 2022-04-02 14:50:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:51:05.000 2022-04-02 14:51:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:51:17.000 2022-04-02 14:51:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:51:29.000 2022-04-02 14:51:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:51:41.000 2022-04-02 14:51:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:51:53.000 2022-04-02 14:51:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:52:05.000 2022-04-02 14:52:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:52:17.000 2022-04-02 14:52:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:52:29.000 2022-04-02 14:52:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:52:41.000 2022-04-02 14:52:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:52:53.000 2022-04-02 14:52:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:53:05.000 2022-04-02 14:53:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:53:17.000 2022-04-02 14:53:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:53:29.000 2022-04-02 14:53:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:53:41.000 2022-04-02 14:53:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:53:53.000 2022-04-02 14:53:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:54:05.000 2022-04-02 14:54:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:54:17.000 2022-04-02 14:54:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:54:29.000 2022-04-02 14:54:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:54:41.000 2022-04-02 14:54:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:54:53.000 2022-04-02 14:54:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:55:05.000 2022-04-02 14:55:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:55:17.000 2022-04-02 14:55:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:55:29.000 2022-04-02 14:55:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:55:41.000 2022-04-02 14:55:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:55:53.000 2022-04-02 14:55:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:56:05.000 2022-04-02 14:56:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:56:17.000 2022-04-02 14:56:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:56:29.000 2022-04-02 14:56:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:56:41.000 2022-04-02 14:56:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:56:53.000 2022-04-02 14:56:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:57:05.000 2022-04-02 14:57:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:57:17.000 2022-04-02 14:57:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:57:29.000 2022-04-02 14:57:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:57:41.000 2022-04-02 14:57:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:57:53.000 2022-04-02 14:57:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:58:05.000 2022-04-02 14:58:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:58:17.000 2022-04-02 14:58:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:58:29.000 2022-04-02 14:58:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:58:41.000 2022-04-02 14:58:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:58:53.000 2022-04-02 14:58:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:59:05.000 2022-04-02 14:59:06.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:59:17.000 2022-04-02 14:59:18.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:59:29.000 2022-04-02 14:59:30.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:59:41.000 2022-04-02 14:59:42.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844
# 2022-04-02 14:59:53.000 2022-04-02 14:59:54.000    SDO        AIA 304.0 .. 304.0     JSOC intensity   NARROW         4096          4096    FULLDISK 64.64844

# %% [markdown]
# We can further specify this query by choosing the cadence (time-sampling) of the data we want to search for and download. This can be achieved by using the Sample attribute. Similar to the Wavelength attributes, this needs to be an astropy Quantity. Lets further specify the search above to only search for data with a cadence of 10 minutes.

# %%
result = Fido.search(a.Time("2022-04-02 12:00", "2022-04-02 15:00"), 
                     a.Instrument("AIA"), 
                     a.Wavelength(171*u.angstrom),
                     a.Sample(10*u.min))

# %%
len(result[0])
# Out:
# 18

# %% [markdown]
# ## 1.3 Downloading the data
#
# Now we can show how data that is queried above can be downloaded. Once the data you have searched for (and filtered etc) is constructed into a query using `Fido.search`, you can then easily download them using `Fido.fetch`.
#
# The data is downloaded via asynchronous and parallel download streams (via parfive), and also allows for failed data downloads to be recognized so that files can be re-requested if not downloaded.
#
# Lets now look at how a `UnifiedResponse` from a `Fido.search` can be passed to `Fido.fetch` to download the data

# %%
files = Fido.fetch(result, site="NSO")
# Out:
# Files Downloaded:   0%|          | 0/18 [00:00<?, ?file/s]
# aia.lev1.171A_2022_04_02T12_00_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T12_10_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T12_30_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T12_40_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T12_20_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_00_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T12_50_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_10_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_20_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_30_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_40_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_50_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T14_00_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T14_10_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T14_20_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T14_30_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T14_40_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T14_50_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]

# %% [markdown]
# These files are downloaded to a local location set in the sunpy.config.file, which by default is ~/sunpy/data/. Fido.fetch returns a parfile.Results object which gives the path to where the files are downloaded to

# %%
print(files[0])
# Out:
# /Users/laurahayes/sunpy/data/aia.lev1.171A_2022_04_02T12_00_09.35Z.image_lev1.fits

# %% [markdown]
# You can also define what directory you want the files to be saved to by passing the directory path to the path keyword in Fido.fetch. For example, I want to download these files to a local directory `./AIA/<name_of_file>`

# %%
Fido.fetch(result, path="./{instrument}/{file}", site="NSO")
# Out:
# Files Downloaded:   0%|          | 0/18 [00:00<?, ?file/s]
# aia.lev1.171A_2022_04_02T12_40_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T12_20_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T12_10_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T12_30_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T12_00_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T12_50_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_00_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_10_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_20_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_30_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_40_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T13_50_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# aia.lev1.171A_2022_04_02T14_00_09.35Z.image_lev1.fits:   0%|          | 0.00/12.0M [00:00<?, ?B/s]

# %% [markdown]
# ## 1. 4 More complex queries
#
# In addition to making a query to one client for one instrument, `Fido` allows the flexibility to search for data from multiple instruments, wavelengths, times etc, even when the data is being obtained through different clients.
#
# This query can be constructed by using the pipe `|` operator, which joins queries together just like the OR operator.
#
# Lets now make a query that searches for both GOES/XRS and AIA data over a particular time period

# %%
result = Fido.search(a.Time("2022-04-02 12:00", "2022-04-02 15:00"), 
                     a.Instrument.xrs  | (a.Instrument.aia & a.Wavelength(304*u.angstrom) & a.Sample(10*u.min)))

# %%
len(result)

# %%
result

# %%
result[0]

# %%
result.all_colnames

# %% [markdown]
# Lets download the GOES XRS data first

# %%
Fido.fetch(result[0, 0], path="./{instrument}/{file}")

# %% [markdown]
# Now lets say we only want to download one AIA file at a particular time, we can also search the table for certain conditions. Lets say we just want the file that closest to 2022-04-02 13:00.

# %%
(np.abs(result[1]["Start Time"] - parse_time("2022-04-02 13:00"))).argmin()

# %%
Fido.fetch(result[1, 6], path="./")

# %% [markdown]
# ## 1. 5 Using External Fido Clients
#
# Within `sunpy` core, we support a number of clients to common data providers. However, the `Fido` search interface is extensible such that external packages can write that their own clients that extend `Fido` in order to additional data sources. One such example is the `sunpy_soar` package which adds a client for the Solar Orbter Archive (SOAR).

# %% [markdown]
# ## SOAR archive searching using sunpy!

# %%
import sunpy_soar

# %% [markdown]
# Note that after importing `sunpy_soar`, the SOAR is now listed as a client that `Fido` will search.

# %%
Fido

# %%
eui_query = Fido.search(a.Time("2022-04-02 12:00", "2022-04-02 15:00"), 
                        a.soar.Product("EUI-FSI174-IMAGE"), 
                        a.Level(2))

# %%
eui_query

# %%
Fido.fetch(eui_query, path="./{instrument}/{file}")

# %% [markdown]
# We can also search for other data products, for example the Solar Orbiter MAG

# %%
mag_query = Fido.search(a.Time("2022-04-02", "2022-04-05"), 
                        a.soar.Product("MAG-RTN-NORMAL-1-MINUTE"), 
                        a.Level(2))

# %%
mag_query

# %%
mag_files = Fido.fetch(mag_query, path="./{instrument}/{file}")

# %%
mag_files

# %% [markdown]
# # Accessing data from the CDAWeb with sunpy - which is very helpful for in-situ data
#
# There is also a CDAWeb client within sunpy. CDAWeb data can be accessed when the `cdaweb.Dataset` attribute is provided to the search.
#
# The data available from the SOAR is also available from the CDAWeb. You may be used to working with this (especially if you mainly work with in-situ observations), so lets go through how the data can also be accessed this way. This is handy, as you can also access many other in-situ measurements from this too.

# %%
res_cdaw = Fido.search(a.Time("2022-04-02", "2022-04-05"), 
                       a.cdaweb.Dataset('SOLO_L2_MAG-RTN-NORMAL-1-MINUTE'))

# %%
res_cdaw

# %%
mag_cdaw_files = Fido.fetch(res_cdaw)

# %% [markdown]
# ## Accessing Metadata queries e.g. information from the HEK
#
# As well as Fido providing an interface to search for data files that can be downloaded, Fido also allows you to query metadata. Currently Fido supports metadata searching from the HEK, HELIO and JSOC.
#
# Similar to what we have seen so far, the search results of these clients are a UnifiedResponse object which can then be indexed and the QueryResponse table accessed like an astropy table. Lets look at an example of how we can use Fido to query the HEK.
#
# Lets query for the active regions defined by SWPC over the past month. This can be done by using the HEK client specific attributes a.hek.attrs

# %%
from sunpy.net import Fido, attrs as a

# %%
result_hek = Fido.search(a.Time("2022-04-02", "2022-04-03"), 
                         a.hek.FL, a.hek.FRM.Name=='SSW Latest Events')

# %%
result_hek["hek"]["event_starttime", "event_peaktime",
                               "event_endtime", "fl_goescls", "ar_noaanum", "frm_name"]

# %%
result_hek = Fido.search(a.Time("2022-04-02", "2022-04-03"), 
                         a.hek.CE)

# %%
result_hek[0][0]

# %%
result_hek[0][0]["hpc_bbox"]
